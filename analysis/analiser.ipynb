# %%
from analysis import Analysis

cora_micro = Analysis('../Cora_microsub_manager_logger_file_1672948551.2461584.txt', dataset='Cora', type='micro', nr_layers = 2)

# %%
cora_micro.explore_hyper_param()
# Out:
# /Users/teodorareu/PycharmProjects/GraphNAS_Project/analysis/analysis.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axis[a][b].set_xticklabels(x, fontdict=None, minor=False)
# /Users/teodorareu/PycharmProjects/GraphNAS_Project/analysis/analysis.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axis[a][b].set_xticklabels(x, fontdict=None, minor=False)
# /Users/teodorareu/PycharmProjects/GraphNAS_Project/analysis/analysis.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axis[a][b].set_xticklabels(x, fontdict=None, minor=False)
# /Users/teodorareu/PycharmProjects/GraphNAS_Project/analysis/analysis.py:113: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axis[a][b].set_xticklabels(x, fontdict=None, minor=False)
